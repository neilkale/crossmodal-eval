# %%
baseline = 0.517

original_data = {
    0: 0.479,
    5: 0.469,
    10: 0.436,
    100: 0.344,
    200: 0.261,
    400: 0.262,
    800: 0.278,
    1100: 0.311
}

new_v1_data = {
    0: 0.517,
    60: 0.514,
    300: 0.514,
    500: 0.517,
    600: 0.518,
    700: 0.526,
    800: 0.519,
    900: 0.524,
    1000: 0.522,
    1100: 0.516
}

new_data = {
    500: 0.52,
    800: 0.513, 
    1100: 0.516,
}

import matplotlib.pyplot as plt

plt.plot(new_v1_data.keys(), new_v1_data.values())
plt.title('MMMU Val Results for Qwen2.5-VL-LoRA-Finetuned')
plt.xlabel('Number of finetuning iterations')
plt.ylabel('Accuracy')
plt.show()
