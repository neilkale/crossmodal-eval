# %%
baseline = 0.517

original_data = {
    0: 0.479,
    5: 0.469,
    10: 0.436,
    100: 0.344,
    200: 0.261,
    400: 0.262,
    800: 0.278,
    1100: 0.311
}

new_v1_data = {
    0: 0.517,
    60: 0.514,
    300: 0.514,
    500: 0.517,
    600: 0.518,
    700: 0.526,
    800: 0.519,
    900: 0.524,
    1000: 0.522,
    1100: 0.516
}

new_data = {
    500: 0.52,
    800: 0.513, 
    1100: 0.516,
}

plus_new_v1_data = {
    200: 0.517,
    400: 0.509,
    600: 0.487,
    800: 0.469,
    1000: 0.452,
    1176: 0.471,
}

new_v1_fix = {
    0: 0.517,
    100: 0.514,
    200: 0.516,
    300: 0.517,
    400: 0.52,
    500: 0.528,
    600: 0.517,
    700: 0.521,
    784: 0.52
}

new_v1_fix2 = {
    0: 0.517,
    100: 0.511,
    200: 0.517,
    300: 0.466,
    400: 0.372,
    500: 0.337,
    600: 0.326,
    700: 0.288,
    784: 0.313
}

new_v1_fix3 = {
    0: 0.517,
    100: 0.508,
    200: 0.513,
    300: 0.516,
    400: 0.519,
    500: 0.523,
    600: 0.52,
    700: 0.519,
    784: 0.516
}

new_v1_fix4 = {
    0: 0.517,
    100: 0.507,
    200: 0.51,
    300: 0.516,
    400: 0.524,
    500: 0.52,
    600: 0.516,
    700: 0.516,
    784: 0.519
}

new_v1_fix5 = {
    0: 0.517,
    # TODO add updated values
    100: 0.508,
    200: 0.508,
    300: 0.521,
    400: 0.519,
    500: 0.522,
    600: 0.520,
    700: 0.526,
    784: 0.52
}

new_v1_fix6 = {
    0: 0.517,
    # TODO add updated values
    200: 0.512,
    400: 0.512,
    600: 0.521,
    800: 0.512,
    1000: 0.508,
    1200: 0.514,
    1400: 0.512, 
    1568: 0.512
}

new_v1_fix7 = {
    0: 0.517,
    100: 0.51,
    200: 0.512,
    300: 0.517,
    400: 0.516,
    500: 0.517,
    600: 0.52,
    700: 0.519,
    764: 0.526,
    800: 0.519,
    900: 0.523,
    1000: 0.523,
    1100: 0.523,
    1176: 0.523,
    1200: 0.521,
    1300: 0.52,
    1400: 0.513,
}

import matplotlib.pyplot as plt

plt.plot(new_v1_fix.keys(), new_v1_fix.values())
plt.title('MMMU Val Results for Qwen2.5-VL-LoRA-Finetuned')
plt.xlabel('Number of finetuning iterations')
plt.ylabel('Accuracy')
plt.show()
